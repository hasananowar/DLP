# %%
# %%
import numpy as np
import pandas as pd
from itertools import combinations
from sklearn.preprocessing import LabelEncoder
# import torch

# %%
df1 = pd.read_csv("DATA/FILT_HB/edges1.csv")
df1
# Out:
#        idx  src  dst  time  dst_idx  ext_roll
# 0        0    0   97     0        5         0
# 1        1    1   98     0       17         0
# 2        2    2   99     0       15         0
# 3        3    3  100     0       24         0
# 4        4    4  101     0       30         0
# ...    ...  ...  ...   ...      ...       ...
# 4169  4169   52  152   100      192         2
# 4170  4170   34  131   100      198         2
# 4171  4171   35  133   100      209         2
# 4172  4172   46  144   100      206         2
# 4173  4173   37  145   100       32         2
#
# [4174 rows x 6 columns]

# %%
df2 = pd.read_csv("DATA/FILT_HB/edges2.csv")
df2
# Out:
#        idx  src  dst  time  dst_idx  ext_roll
# 0        0    0  184     0        5         0
# 1        1    1  185     0       17         0
# 2        2    2  186     0       15         0
# 3        3    3  187     0       24         0
# 4        4    4  188     0       30         0
# ...    ...  ...  ...   ...      ...       ...
# 4169  4169   52  239   100      192         2
# 4170  4170   34  218   100      198         2
# 4171  4171   35  220   100      209         2
# 4172  4172   46  231   100      206         2
# 4173  4173   37  232   100       32         2
#
# [4174 rows x 6 columns]

# %%
# Merge the two DataFrames on 'src' and 'time'
df_merged = pd.merge(df1, df2, on=['src', 'time', 'dst_idx'], suffixes=('_df1', '_df2'))
df_merged
# Out:
#       idx_df1  src  dst_df1  time  dst_idx  ext_roll_df1  idx_df2  dst_df2  \
# 0           0    0       97     0        5             0        0      184
# 1           1    1       98     0       17             0        1      185
# 2           2    2       99     0       15             0        2      186
# 3           3    3      100     0       24             0        3      187
# 4           4    4      101     0       30             0        4      188
# ...       ...  ...      ...   ...      ...           ...      ...      ...
# 4169     4169   52      152   100      192             2     4169      239
# 4170     4170   34      131   100      198             2     4170      218
# 4171     4171   35      133   100      209             2     4171      220
# 4172     4172   46      144   100      206             2     4172      231
# 4173     4173   37      145   100       32             2     4173      232
#
#       ext_roll_df2
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 4169             2
# 4170             2
# 4171             2
# 4172             2
# 4173             2
#
# [4174 rows x 9 columns]

# %%
# Create a new column 'label' where:
# 1 means the same dst_idx in both DataFrames (positive instance),
# 0 means different dst_idx (negative instance).
df_merged['label'] = (df_merged['dst_idx_df1'] == df_merged['dst_idx_df2']).astype(int)

# Optionally, display or save the merged DataFrame
df_merged
# Out:
#       idx_df1  src  dst_df1  time  dst_idx_df1  ext_roll_df1  idx_df2  \
# 0           0    0       97     0            5             0        0
# 1           1    1       98     0           17             0        1
# 2           2    2       99     0           15             0        2
# 3           3    3      100     0           24             0        3
# 4           4    4      101     0           30             0        4
# ...       ...  ...      ...   ...          ...           ...      ...
# 4307     4169   52      152   100          192             2     4169
# 4308     4170   34      131   100          198             2     4170
# 4309     4171   35      133   100          209             2     4171
# 4310     4172   46      144   100          206             2     4172
# 4311     4173   37      145   100           32             2     4173
#
#       dst_df2  dst_idx_df2  ext_roll_df2  label
# 0         184            5             0      1
# 1         185           17             0      1
# 2         186           15             0      1
# 3         187           24             0      1
# 4         188           30             0      1
# ...       ...          ...           ...    ...
# 4307      239          192             2      1
# 4308      218          198             2      1
# 4309      220          209             2      1
# 4310      231          206             2      1
# 4311      232           32             2      1
#
# [4312 rows x 11 columns]

# %%
df_merged.to_csv("merged_with_labels.csv", index=False)

# %%
print( max(int(df1['src'].max()), int(df1['dst'].max())) + 1)

# %%
# Read the CSV file
csv_data = pd.read_csv("DATA/FILT_HB/angle_node_features.csv")

# Drop the first column
csv_data = csv_data.iloc[:, 1:]

# Convert the DataFrame to a PyTorch tensor
tensor_data = torch.tensor(csv_data.values, dtype=torch.float32)

# Adjust the tensor data index to start from 184
tensor_data[:, 0] += 184

# Save the tensor to a .pt file
torch.save(tensor_data, "DATA/FILT_HB/node_features2.pt")

# Load the tensor from the .pt file
loaded_tensor = torch.load("DATA/FILT_HB/node_features2.pt")

# Display the loaded tensor
print("Loaded Tensor:")
print(loaded_tensor)
# Out:
# Loaded Tensor:
# tensor([[185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [186.],
#         [186.],
#         [186.],
#         [186.],
#         [186.],
#         [186.],
#         [186.],
#         [186.],
#         [187.],
#         [187.],
#         [187.],
#         [187.],
#         [187.],
#         [187.],
#         [187.],
#         [187.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [195.],
#         [185.],
#         [185.],
#         [186.],
#         [186.],
#         [186.],
#         [187.],
#         [187.],
#         [188.],
#         [188.],
#         [185.],
#         [186.],
#         [186.],
#         [187.],
#         [187.],
#         [188.],
#         [185.],
#         [185.],
#         [186.],
#         [188.],
#         [185.],
#         [186.],
#         [186.],
#         [187.],
#         [187.],
#         [186.],
#         [187.],
#         [186.],
#         [185.],
#         [185.],
#         [186.],
#         [188.],
#         [185.],
#         [188.],
#         [187.],
#         [185.],
#         [185.],
#         [187.],
#         [188.],
#         [185.],
#         [186.],
#         [187.],
#         [187.],
#         [185.],
#         [188.],
#         [186.],
#         [187.],
#         [186.],
#         [186.],
#         [188.],
#         [185.],
#         [185.],
#         [186.],
#         [186.],
#         [187.],
#         [188.],
#         [186.],
#         [187.],
#         [187.],
#         [188.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [185.],
#         [186.],
#         [186.],
#         [186.],
#         [186.],
#         [186.],
#         [186.],
#         [186.],
#         [186.],
#         [187.],
#         [187.],
#         [187.],
#         [187.],
#         [187.],
#         [187.],
#         [187.],
#         [187.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [188.],
#         [185.],
#         [185.],
#         [185.],
#         [186.],
#         [186.],
#         [186.],
#         [187.],
#         [187.],
#         [188.],
#         [188.],
#         [185.],
#         [185.],
#         [185.],
#         [186.],
#         [186.],
#         [187.],
#         [187.],
#         [188.],
#         [185.],
#         [185.],
#         [186.],
#         [188.],
#         [185.],
#         [187.],
#         [187.],
#         [186.],
#         [186.],
#         [185.],
#         [186.],
#         [188.],
#         [185.],
#         [185.],
#         [187.],
#         [185.],
#         [186.],
#         [187.],
#         [185.],
#         [186.],
#         [187.],
#         [186.],
#         [185.],
#         [185.],
#         [186.],
#         [186.],
#         [188.],
#         [187.],
#         [188.],
#         [186.],
#         [187.]])

# %%
# Load the tensor from the .pt file
loaded_tensor = torch.load("DATA/FILT_HB/node_features2.pt")

# Display the loaded tensor
print("Loaded Tensor:")
print(loaded_tensor.shape)
# Out:
# Loaded Tensor:
# torch.Size([184, 1])

# %%
df = pd.read_csv("HB1000frames.csv")
df
# Out:
#                  X          Y          Z Atom_Name Residue_Name  Residue_ID  \
# 0        12.759892   2.253709  33.260902        C1          CSP           1
# 1        12.862613   3.581455  34.023949        C2          CSP           1
# 2        11.457548   4.321817  34.003315        C3          CSP           1
# 3        10.981806   4.421790  32.537914        C4          CSP           1
# 4        11.038748   3.091581  31.915064        O5          CSP           1
# ...            ...        ...        ...       ...          ...         ...
# 6125995  19.644390  67.404449  66.474434        H8          SFL          14
# 6125996  20.729301  69.015923  65.032753        H9          SFL          14
# 6125997  29.891628  67.217079  64.978050       H10          SFL          14
# 6125998  29.860481  69.114059  68.780251       H11          SFL          14
# 6125999  31.024197  68.543945  66.798332       H12          SFL          14
#
#         Atom_Type  Timeframe
# 0              cb     255000
# 1              cb     255000
# 2              cb     255000
# 3              cb     255000
# 4              ob     255000
# ...           ...        ...
# 6125995        ha     255999
# 6125996        ha     255999
# 6125997        ha     255999
# 6125998        ha     255999
# 6125999        ha     255999
#
# [6126000 rows x 8 columns]

# %%
# Filter the dataframe for Timeframe 255099
filtered_df = df[df['Timeframe'] == 255099]

# Save the filtered dataframe to a CSV file
filtered_df.to_csv("filtered_timeframe_255099.csv", index=False)

print("Filtered data saved to 'filtered_timeframe_255099.csv'")
# Out:
# Filtered data saved to 'filtered_timeframe_255099.csv'

# %%
dist_df = pd.read_csv("DATA/HB/dist_df_100time.csv")
angle_df = pd.read_csv("DATA/HB/angle_df_100time.csv")

# %%
dist_df
# Out:
#             src     dst    time   distance  src_mol  dst_mol  nh_id  label
# 0          O5_1   N11_1  255000   4.435484        1        1      1      1
# 1          O5_1   N23_1  255000   5.677049        1        1      2      1
# 2          O5_1   N35_1  255000   6.328246        1        1      3      1
# 3          O5_1   N55_1  255000   6.667776        1        1      4      1
# 4          O5_1   N67_1  255000   7.467732        1        1      5      1
# ...         ...     ...     ...        ...      ...      ...    ...    ...
# 12873595  O2_14  N727_4  255099  79.479108       14        4    212      2
# 12873596  O2_14  N739_4  255099  75.781733       14        4    213      2
# 12873597  O2_14  N759_4  255099  75.197622       14        4    214      2
# 12873598  O2_14  N771_4  255099  84.087391       14        4    215      2
# 12873599  O2_14  N783_4  255099  83.915797       14        4    216      2
#
# [12873600 rows x 8 columns]

# %%
angle_df
# Out:
#             src     dst    time       angle  src_mol  dst_mol  nh_id  label
# 0          O5_1    H9_1  255000   61.040505        1        1      1      1
# 1          O5_1   H19_1  255000   73.524710        1        1      2      1
# 2          O5_1   H29_1  255000   88.194570        1        1      3      1
# 3          O5_1   H46_1  255000  120.540965        1        1      4      1
# 4          O5_1   H56_1  255000  115.887955        1        1      5      1
# ...         ...     ...     ...         ...      ...      ...    ...    ...
# 12873595  O2_14  H611_4  255099  166.764098       14        4    212      2
# 12873596  O2_14  H621_4  255099   62.206380       14        4    213      2
# 12873597  O2_14  H638_4  255099   99.980679       14        4    214      2
# 12873598  O2_14  H648_4  255099  137.762045       14        4    215      2
# 12873599  O2_14  H658_4  255099   95.823211       14        4    216      2
#
# [12873600 rows x 8 columns]

# %%
dist_df['time'] -= 255000
angle_df['time'] -= 255000

# %%
# Filter DataFrames
filtered_dist_df = dist_df[dist_df['distance'] <= 3.5].reset_index(drop=True)
filtered_angle_df = angle_df[(angle_df['angle'] >= 135) & (angle_df['angle'] < 180)].reset_index(drop=True)


# Find common keys
common_keys = pd.merge(
    filtered_dist_df[['time', 'src', 'nh_id']],
    filtered_angle_df[['time', 'src', 'nh_id']],
    on=['time', 'src', 'nh_id']
)

filtered_dist_df = filtered_dist_df.merge(common_keys, on=['time', 'src', 'nh_id'])
filtered_angle_df = filtered_angle_df.merge(common_keys, on=['time', 'src', 'nh_id'])

# Display the filtered DataFrames
print("Filtered Distance DataFrame:")
print(filtered_dist_df)

print("\nFiltered Angle DataFrame:")
print(filtered_angle_df)
# Out:
# Filtered Distance DataFrame:
#          src     dst  time  distance  src_mol  dst_mol  nh_id  label
# 0      O10_1   N79_1     0  3.010041        1        1      6      1
# 1     O184_1  N255_1     0  3.252512        1        1     18      1
# 2     O210_1  N231_1     0  2.668763        1        1     16      1
# 3     O284_1  N363_1     0  3.411373        1        1     25      1
# 4     O406_1  N451_1     0  3.048154        1        1     31      1
# ...      ...     ...   ...       ...      ...      ...    ...    ...
# 4155  O430_4  N451_4    99  3.339441        4        4    193      1
# 4156  O518_4  N539_4    99  3.117341        4        4    199      1
# 4157  O626_4  N695_4    99  2.918977        4        4    210      1
# 4158   O2_11  N407_1    99  2.896783       11        1     28      2
# 4159   O2_11  N475_1    99  2.937560       11        1     33      2
#
# [4160 rows x 8 columns]
#
# Filtered Angle DataFrame:
#          src     dst  time       angle  src_mol  dst_mol  nh_id  label
# 0      O10_1   H66_1     0  161.759281        1        1      6      1
# 1     O184_1  H214_1     0  136.799665        1        1     18      1
# 2     O210_1  H194_1     0  153.506310        1        1     16      1
# 3     O284_1  H305_1     0  146.807099        1        1     25      1
# 4     O406_1  H379_1     0  165.675379        1        1     31      1
# ...      ...     ...   ...         ...      ...      ...    ...    ...
# 4155  O430_4  H379_4    99  154.582311        4        4    193      1
# 4156  O518_4  H453_4    99  151.279809        4        4    199      1
# 4157  O626_4  H584_4    99  166.260034        4        4    210      1
# 4158   O2_11  H342_1    99  165.328913       11        1     28      2
# 4159   O2_11  H399_1    99  138.959952       11        1     33      2
#
# [4160 rows x 8 columns]

# %%
def map_numeric_indices(dist_df, angle_df):
    """
    Map 'src' and 'dst' columns to numeric indices starting from 1 for consistent mapping.

    Parameters:
    - dist_df (pd.DataFrame): Distance DataFrame
    - angle_df (pd.DataFrame): Angle DataFrame

    Returns:
    - dist_df (pd.DataFrame): Updated Distance DataFrame with numeric indices
    - angle_df (pd.DataFrame): Updated Angle DataFrame with numeric indices
    """
    # Combine src and dst values for consistent mapping
    combined_values = pd.concat([
        dist_df['src'], dist_df['dst'], 
        angle_df['src'], angle_df['dst']
    ])

    # Use factorize to assign numeric indices starting from 0
    numeric_indices, _ = pd.factorize(combined_values)

    # Add 1 to ensure indices start from 1
    numeric_indices += 1

    # Map src and dst directly to numeric indices using factorized output
    mapping = pd.Series(numeric_indices, index=combined_values).to_dict()

    # Replace src and dst with numeric indices starting from 1
    for df in [dist_df, angle_df]:
        df['src'] = df['src'].map(mapping)
        df['dst'] = df['dst'].map(mapping)
    
    return dist_df, angle_df


dist_df, angle_df = map_numeric_indices(dist_df, angle_df)


# Display the updated DataFrames
print("Distance DataFrame:")
print(dist_df)

print("\nAngle DataFrame:")
print(angle_df)
# Out:
# Updated Distance DataFrame:
#           src  dst  time   distance  src_mol  dst_mol  nh_id  label
# 0           1  597     0   4.435484        1        1      1      1
# 1           1  598     0   5.677049        1        1      2      1
# 2           1  599     0   6.328246        1        1      3      1
# 3           1  600     0   6.667776        1        1      4      1
# 4           1  601     0   7.467732        1        1      5      1
# ...       ...  ...   ...        ...      ...      ...    ...    ...
# 12873595  596  808    99  79.479108       14        4    212      2
# 12873596  596  809    99  75.781733       14        4    213      2
# 12873597  596  810    99  75.197622       14        4    214      2
# 12873598  596  811    99  84.087391       14        4    215      2
# 12873599  596  812    99  83.915797       14        4    216      2
#
# [12873600 rows x 8 columns]
#
# Updated Angle DataFrame:
#           src   dst  time       angle  src_mol  dst_mol  nh_id  label
# 0           1   813     0   61.040505        1        1      1      1
# 1           1   814     0   73.524710        1        1      2      1
# 2           1   815     0   88.194570        1        1      3      1
# 3           1   816     0  120.540965        1        1      4      1
# 4           1   817     0  115.887955        1        1      5      1
# ...       ...   ...   ...         ...      ...      ...    ...    ...
# 12873595  596  1024    99  166.764098       14        4    212      2
# 12873596  596  1025    99   62.206380       14        4    213      2
# 12873597  596  1026    99   99.980679       14        4    214      2
# 12873598  596  1027    99  137.762045       14        4    215      2
# 12873599  596  1028    99   95.823211       14        4    216      2
#
# [12873600 rows x 8 columns]
# Updated Distance DataFrame:
#       src  dst  time  distance  src_mol  dst_mol  nh_id  label
# 0       1  101     0  3.010041        1        1      6      1
# 1       2  102     0  3.252512        1        1     18      1
# 2       3  103     0  2.668763        1        1     16      1
# 3       4  104     0  3.411373        1        1     25      1
# 4       5  105     0  3.048154        1        1     31      1
# ...   ...  ...   ...       ...      ...      ...    ...    ...
# 4155   54  156    99  3.339441        4        4    193      1
# 4156   36  136    99  3.117341        4        4    199      1
# 4157   37  138    99  2.918977        4        4    210      1
# 4158   39  140    99  2.896783       11        1     28      2
# 4159   39  149    99  2.937560       11        1     33      2
#
# [4160 rows x 8 columns]
#
# Updated Angle DataFrame:
#       src  dst  time       angle  src_mol  dst_mol  nh_id  label
# 0       1  188     0  161.759281        1        1      6      1
# 1       2  189     0  136.799665        1        1     18      1
# 2       3  190     0  153.506310        1        1     16      1
# 3       4  191     0  146.807099        1        1     25      1
# 4       5  192     0  165.675379        1        1     31      1
# ...   ...  ...   ...         ...      ...      ...    ...    ...
# 4155   54  243    99  154.582311        4        4    193      1
# 4156   36  223    99  151.279809        4        4    199      1
# 4157   37  225    99  166.260034        4        4    210      1
# 4158   39  227    99  165.328913       11        1     28      2
# 4159   39  236    99  138.959952       11        1     33      2
#
# [4160 rows x 8 columns]

# %%
filtered_dist_df, filtered_angle_df = map_numeric_indices(filtered_dist_df, filtered_angle_df)

# Display the updated DataFrames
print("Updated Distance DataFrame:")
print(filtered_dist_df)

print("\nUpdated Angle DataFrame:")
print(filtered_angle_df)
# Out:
# Updated Distance DataFrame:
#        idx  src  dst  time  distance  src_mol  dst_mol  nh_id  label  ext_roll
# 0        0    1  101     0  3.010041        1        1      6      1         0
# 1        1    2  102     0  3.252512        1        1     18      1         0
# 2        2    3  103     0  2.668763        1        1     16      1         0
# 3        3    4  104     0  3.411373        1        1     25      1         0
# 4        4    5  105     0  3.048154        1        1     31      1         0
# ...    ...  ...  ...   ...       ...      ...      ...    ...    ...       ...
# 4155  4155   54  156    99  3.339441        4        4    193      1         2
# 4156  4156   36  136    99  3.117341        4        4    199      1         2
# 4157  4157   37  138    99  2.918977        4        4    210      1         2
# 4158  4158   39  140    99  2.896783       11        1     28      2         2
# 4159  4159   39  149    99  2.937560       11        1     33      2         2
#
# [4160 rows x 10 columns]
#
# Updated Angle DataFrame:
#        idx  src  dst  time       angle  src_mol  dst_mol  nh_id  label  \
# 0        0    1  188     0  161.759281        1        1      6      1
# 1        1    2  189     0  136.799665        1        1     18      1
# 2        2    3  190     0  153.506310        1        1     16      1
# 3        3    4  191     0  146.807099        1        1     25      1
# 4        4    5  192     0  165.675379        1        1     31      1
# ...    ...  ...  ...   ...         ...      ...      ...    ...    ...
# 4155  4155   54  243    99  154.582311        4        4    193      1
# 4156  4156   36  223    99  151.279809        4        4    199      1
# 4157  4157   37  225    99  166.260034        4        4    210      1
# 4158  4158   39  227    99  165.328913       11        1     28      2
# 4159  4159   39  236    99  138.959952       11        1     33      2
#
#       ext_roll
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 4155         2
# 4156         2
# 4157         2
# 4158         2
# 4159         2
#
# [4160 rows x 10 columns]

# %%
# Function to process DataFrame and save it to a CSV file
def process_and_save_dataframe(df, filename):
    """
    Process the input DataFrame to add 'ext_roll' and 'idx' columns.
    Convert all columns to integers before saving.
    Save the processed DataFrame to a specified CSV file.

    Parameters:
    - df (pd.DataFrame): Input DataFrame
    - filename (str): Output file path
    """
    num_rows = len(df)

    # Initialize 'ext_roll' column with zeros
    df['ext_roll'] = 0

    # Assign 1 to the middle 15% rows and 2 to the last 15% rows
    df.loc[int(num_rows * 0.7):int(num_rows * 0.85) - 1, 'ext_roll'] = 1
    df.loc[int(num_rows * 0.85):, 'ext_roll'] = 2

    # Insert an 'idx' column at the beginning
    df.insert(0, 'idx', range(len(df)))

    # Reindex and retain only the required columns
    df = df[['idx', 'src', 'dst', 'time', 'label', 'ext_roll', 'nh_id']]

    # # Convert all columns to integers
    # for col in df.columns:
    #     df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)

    # Save the updated DataFrame to the specified CSV file
    df.to_csv(filename, index=False)
    print(f"Saved updated DataFrame to {filename}")

    return df

# %%
process_and_save_dataframe(dist_df, 'DATA/HB/test_edges1.csv')
process_and_save_dataframe(angle_df, 'DATA/HB/test_edges2.csv')

process_and_save_dataframe(filtered_dist_df, 'DATA/HB/filtered_edges1.csv')
process_and_save_dataframe(filtered_angle_df, 'DATA/HB/filtered_edges2.csv')
# Out:
# Saved updated DataFrame to DATA/HB/test_edges1.csv
# Saved updated DataFrame to DATA/HB/test_edges2.csv
# Saved updated DataFrame to DATA/HB/filtered_edges1.csv
# Saved updated DataFrame to DATA/HB/filtered_edges2.csv
#        idx  src  dst  time  label  ext_roll  nh_id
# 0        0    1  188     0      1         0      6
# 1        1    2  189     0      1         0     18
# 2        2    3  190     0      1         0     16
# 3        3    4  191     0      1         0     25
# 4        4    5  192     0      1         0     31
# ...    ...  ...  ...   ...    ...       ...    ...
# 4155  4155   54  243    99      1         2    193
# 4156  4156   36  223    99      1         2    199
# 4157  4157   37  225    99      1         2    210
# 4158  4158   39  227    99      2         2     28
# 4159  4159   39  236    99      2         2     33
#
# [4160 rows x 7 columns]

# %%
final_dist = pd.read_csv("DATA/HB/test_edges1.csv")
final_angle = pd.read_csv("DATA/HB/test_edges2.csv")

# Display the first few rows of both DataFrames
print("Final Distance DataFrame:")
print(final_dist)

print("\nFinal Angle DataFrame:")
print(final_angle)
# Out:
# Updated Distance DataFrame:
#                idx  src  dst  time  label  ext_roll  nh_id
# 0                0    1  597     0      1         0      1
# 1                1    1  598     0      1         0      2
# 2                2    1  599     0      1         0      3
# 3                3    1  600     0      1         0      4
# 4                4    1  601     0      1         0      5
# ...            ...  ...  ...   ...    ...       ...    ...
# 12873595  12873595  596  808    99      2         2    212
# 12873596  12873596  596  809    99      2         2    213
# 12873597  12873597  596  810    99      2         2    214
# 12873598  12873598  596  811    99      2         2    215
# 12873599  12873599  596  812    99      2         2    216
#
# [12873600 rows x 7 columns]
#
# Updated Angle DataFrame:
#                idx  src   dst  time  label  ext_roll  nh_id
# 0                0    1   813     0      1         0      1
# 1                1    1   814     0      1         0      2
# 2                2    1   815     0      1         0      3
# 3                3    1   816     0      1         0      4
# 4                4    1   817     0      1         0      5
# ...            ...  ...   ...   ...    ...       ...    ...
# 12873595  12873595  596  1024    99      2         2    212
# 12873596  12873596  596  1025    99      2         2    213
# 12873597  12873597  596  1026    99      2         2    214
# 12873598  12873598  596  1027    99      2         2    215
# 12873599  12873599  596  1028    99      2         2    216
#
# [12873600 rows x 7 columns]

# %%
final_filt_dist = pd.read_csv("DATA/HB/filtered_edges1.csv")
final_filt_angle = pd.read_csv("DATA/HB/filtered_edges2.csv")
# Display the first few rows of both DataFrames
print("Filtered Distance DataFrame:")
print(final_filt_dist)

print("\nFiltered Angle DataFrame:")
print(final_filt_angle)
# Out:
# Filtered Distance DataFrame:
#        idx  src  dst  time  label  ext_roll  nh_id
# 0        0    1  101     0      1         0      6
# 1        1    2  102     0      1         0     18
# 2        2    3  103     0      1         0     16
# 3        3    4  104     0      1         0     25
# 4        4    5  105     0      1         0     31
# ...    ...  ...  ...   ...    ...       ...    ...
# 4155  4155   54  156    99      1         2    193
# 4156  4156   36  136    99      1         2    199
# 4157  4157   37  138    99      1         2    210
# 4158  4158   39  140    99      2         2     28
# 4159  4159   39  149    99      2         2     33
#
# [4160 rows x 7 columns]
#
# Filtered Angle DataFrame:
#        idx  src  dst  time  label  ext_roll  nh_id
# 0        0    1  188     0      1         0      6
# 1        1    2  189     0      1         0     18
# 2        2    3  190     0      1         0     16
# 3        3    4  191     0      1         0     25
# 4        4    5  192     0      1         0     31
# ...    ...  ...  ...   ...    ...       ...    ...
# 4155  4155   54  243    99      1         2    193
# 4156  4156   36  223    99      1         2    199
# 4157  4157   37  225    99      1         2    210
# 4158  4158   39  227    99      2         2     28
# 4159  4159   39  236    99      2         2     33
#
# [4160 rows x 7 columns]

# %%
# unique_src_numbers = final_angle['src'].unique()
# print(len(unique_src_numbers))
# Out:
# 596
